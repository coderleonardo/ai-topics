# %%
from agentic_patterns import ReflectionAgent

# %%
agent = ReflectionAgent()

# %%
generation_system_prompt = "You are a Python programmer tasked with generating high quality Python code"

reflection_system_prompt = "You are Andrej Karpathy, an experienced computer scientist"

user_msg = "Generate a Python implementation of the Insertion Sort algorithm"

# %%
final_response = agent.run(
    user_msg=user_msg,
    generation_system_prompt=generation_system_prompt,
    reflection_system_prompt=reflection_system_prompt,
    n_steps=1,
    verbose=1,
)
# Out:
# ==================================================
# STEP 1/1
# ==================================================
#
#
#
# GENERATION
#
#  **Insertion Sort Algorithm Implementation in Python**
# ======================================================
#
# Here is an efficient and well-structured Python implementation of the Insertion Sort algorithm:
#
# ```python
# def insertion_sort(arr):
#     """
#     Sorts an array using the Insertion Sort algorithm.
#
#     Args:
#         arr (list): The input array to be sorted.
#
#     Returns:
#         list: A new sorted array.
#     """
#
#     # Create a copy of the original array to avoid modifying it in-place
#     sorted_arr = arr[:]
#
#     for i in range(1, len(sorted_arr)):
#         key = sorted_arr[i]
#         j = i - 1
#
#         # Move elements of sorted_arr[0..i-1], that are greater than key,
#         # to one position ahead of their current position
#         while j >= 0 and sorted_arr[j] > key:
#             sorted_arr[j + 1] = sorted_arr[j]
#             j -= 1
#
#         # Place the key element at its correct position in sorted_arr[0..i]
#         sorted_arr[j + 1] = key
#
#     return sorted_arr
# ```
#
# **Example Usage:**
# ```python
# # Test the implementation with an unsorted array
# arr = [64, 34, 25, 12, 22, 11, 90]
#
# print("Original Array:", arr)
#
# # Sort the array using Insertion Sort
# sorted_arr = insertion_sort(arr)
#
# print("Sorted Array:", sorted_arr)
# ```
#
# **Output:**
# ```
# Original Array: [64, 34, 25, 12, 22, 11, 90]
# Sorted Array: [11, 12, 22, 25, 34, 64, 90]
# ```
#
# This implementation has a time complexity of O(n^2), making it less efficient than other sorting algorithms like QuickSort or MergeSort for large datasets. However, Insertion Sort is suitable for small datasets or nearly-sorted arrays.
#
# If you have any critiques or suggestions, please feel free to provide them!
#
#
# REFLECTION
#
#  **Critique and Recommendations**
# ================================
#
# Overall, the implementation looks clean and well-structured. Here are some specific comments and recommendations:
#
# *   **Functionality:** The Insertion Sort algorithm is correctly implemented, and the code follows standard professional guidelines for naming and commenting.
# *   **Readability:**
#
#     *   The variable names could be more descriptive. For example, `arr` could be `input_array`, and `sorted_arr` could be `sorted_input_array`. This would make it clearer what each array represents.
#     *   Some of the comments are unclear or redundant. For instance, the comment "Create a copy of the original array to avoid modifying it in-place" is not necessary, as this behavior is already guaranteed by creating a slice (`arr[:]`).
# *   **Performance:** As mentioned earlier, Insertion Sort has a time complexity of O(n^2), which makes it less efficient for large datasets. While the code is well-structured and readable, it may be beneficial to include a note about the algorithm's limitations in terms of performance.
# *   **Testing:**
#
#     *   The example usage includes an unsorted array, but you might want to consider adding additional test cases (e.g., a sorted array, an array with duplicates) to ensure that the function works correctly in all scenarios.
#
# **Recommendations for Improvement**
# -----------------------------------
#
# 1.  Use more descriptive variable names.
# 2.  Add additional comments or docstrings to clarify any complex sections of code.
# 3.  Consider including a note about the algorithm's limitations in terms of performance.
# 4.  Add more comprehensive test cases (e.g., sorted array, array with duplicates).
# 5.  Consider adding input validation to ensure that the function can handle edge cases (e.g., empty arrays).
#
# Here is an updated version incorporating some of these suggestions:
#
# ```python
# def insertion_sort(sorted_input_array):
#     """
#     Sorts a list of elements using the Insertion Sort algorithm.
#
#     Args:
#         sorted_input_array (list): The input array to be sorted.
#
#     Returns:
#         list: A new sorted array.
#
#     Note:
#         This implementation has a time complexity of O(n^2), making it less efficient
#         than other sorting algorithms for large datasets.
#     """
#
#     # Create a copy of the original array to avoid modifying it in-place
#     sorted_array = sorted_input_array[:]
#
#     for i in range(1, len(sorted_array)):
#         key = sorted_array[i]
#         j = i - 1
#
#         # Move elements of sorted_array[0..i-1], that are greater than key,
#         # to one position ahead of their current position
#         while j >= 0 and sorted_array[j] > key:
#             sorted_array[j + 1] = sorted_array[j]
#             j -= 1
#
#         # Place the key element at its correct position in sorted_array[0..i]
#         sorted_array[j + 1] = key
#
#     return sorted_array
# ```
#
# **Example Usage:**
# ```python
# # Test the implementation with an unsorted array
# input_array = [64, 34, 25, 12, 22, 11, 90]
#
# print("Original Array:", input_array)
#
# # Sort the array using Insertion Sort
# sorted_array = insertion_sort(input_array)
#
# print("Sorted Array:", sorted_array)
# ```
#
# **Output:**
# ```
# Original Array: [64, 34, 25, 12, 22, 11, 90]
# Sorted Array: [11, 12, 22, 25, 34, 64, 90]
# ```
